# %%
from PIL import Image
from matplotlib import pyplot
from numpy import asarray
img = Image.open("groupGray.jpg")
img_2 = Image.open("boothiGray.jpg")
img_array = asarray(img)
img_2_array = asarray(img_2)

# %%
print(img.format)
# Out:
# JPEG

# %%
print(img.size)
# Out:
# (1024, 512)

# %%
print(img.mode)
# Out:
# L

# %%
pyplot.imshow(img,cmap="hot")

# %%
print(type(img_array))
print(type(img_2_array))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(img_array.shape)
# Out:
# (512, 1024)

# %%
print(img_2_array.shape)
# Out:
# (35, 29)

# %%
print(img_2_array)
# Out:
# [[ 24  27  19 ...  22  22  22]
#  [ 25  24  22 ...  21  21  20]
#  [ 29  27  33 ...  26  26  26]
#  ...
#  [ 23  16  11 ...  15  17  22]
#  [ 19  57  90 ...  23  25  25]
#  [137 160 182 ...  61  29  19]]

# %%
slice = img_array[:3,:300]

# %%
slice.shape
# Out:
# (512, 300)

# %%
slice.size
# Out:
# 153600

# %%
pyplot.imshow(slice,cmap="hot")
