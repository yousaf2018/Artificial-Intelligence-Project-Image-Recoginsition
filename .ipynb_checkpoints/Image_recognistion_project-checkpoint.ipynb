# %%
#Using matplotlib for image loading and ploting
#Using numpy library to manipulate images
from matplotlib import pyplot
import numpy as np
import math

# %%
groupImage = pyplot.imread("groupGray.jpg")
baba_g = pyplot.imread("boothiGray.jpg")
pyplot.imshow(groupImage)

# %%
#Getting height and width of both images for template matching
shape_baba_image = baba_g.shape
shape_group_image = groupImage.shape
height_baba_image = shape_baba_image[0]
width_baba_image = shape_baba_image[1]
height_group_image = shape_group_image[0]
width_group_image = shape_group_image[1]

# %%
#Generating random numbers for 50 population
random_50_height_group_image = np.random.randint(0,height_group_image+1,100)
random_50_width_group_image = np.random.randint(0,width_group_image+1,100)
height_baba_image
# Out:
# 35

# %%
#Slicing 50 population of same shape as baba g shape
#Getting fitness of each sliced image with baba g
pop_50 = []
for i in range(100):
    #checking slice height is it out side group image 
    random_height = random_50_height_group_image[i]
    check_height = height_group_image - random_height
    if check_height>=height_baba_image:
        random_width = random_50_width_group_image[i]
        check_width = width_group_image - random_width
        if check_width>=width_baba_image:
            temp_slice = groupImage[random_50_height_group_image[i]:random_50_height_group_image[i]+height_baba_image,
                                   random_50_width_group_image[i]:random_50_width_group_image[i]+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            pop_50.append([Fitness,random_50_height_group_image[i],random_50_width_group_image[i]])
        else:
            width = width_group_image-width_baba_image
            temp_slice = groupImage[random_50_height_group_image[i]:random_50_height_group_image[i]+height_baba_image,
                                    width:width+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            pop_50.append([Fitness,random_50_height_group_image[i],random_50_width_group_image[i]])
            
    else:
        height = height_group_image-height_baba_image
        random_width = random_50_width_group_image[i]
        check_width = width_group_image - random_width
        if check_width>=width_baba_image:
            temp_slice = groupImage[height:height+height_baba_image,
                                   random_50_width_group_image[i]:random_50_width_group_image[i]+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            pop_50.append([Fitness,random_50_height_group_image[i],random_50_width_group_image[i]])
        else:
            width = width_group_image-width_baba_image
            temp_slice = groupImage[height:height+height_baba_image,
                                    width:width+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            pop_50.append([Fitness,random_50_height_group_image[i],random_50_width_group_image[i]])

# %%
sorted_pop_50 = sorted(pop_50,key=lambda x:x[0],reverse=True)

# %%
def Cross_over_mutation(x1,y1,x2,y2,height_group_image,width_group_image):
    total_bits_height = int(math.ceil(math.log2(height_group_image)))
    total_bits_width = int(math.ceil(math.log2(width_group_image)))
    x1_bin = bin(x1)
    len_x1_bin = len(x1_bin[2:])
    y1_bin = bin(y1)
    len_y1_bin = len(y1_bin[2:])
    x2_bin = bin(x2)
    len_x2_bin = len(x2_bin[2:])
    y2_bin = bin(y2)
    len_y2_bin = len(y2_bin[2:])
    x1_x2 = x1_bin[2:] + x2_bin[2:]
    y1_y2 = y1_bin[2:] + y2_bin[2:]
    check1 = total_bits_height - len(x1_x2)
    check2 = total_bits_width - len(y1_y2)
    if check1 > 0:
        for i in range(check1):
            x1_x2 = x1_x2 + '0'
        if check2 > 0:
            for i in range(check2):
                y1_y2 = y1_y2 + '0'
    x1_x2 = list(map(int,x1_x2))
    y1_y2 = list(map(int,y1_y2))
    #Cross over
    len_x1_x2 = len(x1_x2)
    len_y1_y2 = len(y1_y2)
    for i in range(len_x1_x2//3):
        random_index_x1_x2 = np.random.randint(0,len_x1_x2)
        random_index_y1_y2 = np.random.randint(0,len_y1_y2)
        #swaping
        temp = y1_y2[random_index_y1_y2]
        y1_y2[random_index_y1_y2] = x1_x2[random_index_x1_x2]
        x1_x2[random_index_x1_x2] = temp
        #mutation
        random_index_x1_x2 = np.random.randint(0,len_x1_x2)
        random_index_y1_y2 = np.random.randint(0,len_y1_y2)
        check = x1_x2[random_index_x1_x2]
        if check == 0:
            x1_x2[random_index_x1_x2] = 1
            check2 = y1_y2[random_index_y1_y2]
            if check2 == 0:
                y1_y2[random_index_y1_y2] = 1
            else:
                y1_y2[random_index_y1_y2] = 0
        else:
            x1_x2[random_index_x1_x2] = 0
            check2 = y1_y2[random_index_y1_y2]
            if check2 == 0:
                y1_y2[random_index_y1_y2] = 1
            else:
                y1_y2[random_index_y1_y2] = 0
    x1_x2 = list(map(str,x1_x2))
    y1_y2 = list(map(str,y1_y2))
    x1_x2 = ''.join(map(str,x1_x2))
    x1 = x1_x2[:len_x1_bin]
    x2 = x1_x2[len_x1_bin:]
    y1_y2 = ''.join(map(str,y1_y2))
    y1 = y1_y2[:len_y1_bin]
    y2 = y1_y2[len_y1_bin:]
    x1 = "0b" + x1
    x1 = int(x1,2)
    x2 = "0b" + x2
    x2 = int(x2,2)
    y1 = "0b" + y1
    y1 = int(y1,2)
    y2 = "0b" + y2
    y2 = int(y2,2)
    return x1,y1,x2,y2
def fitness(x,y,height_baba_image,width_baba_image,height_group_image,width_group_image,groupImage,baba_g):
    check_height = height_group_image - x
    if check_height >= height_baba_image:
        check_width = width_group_image - y
        if check_width >= width_baba_image:
            temp_slice = groupImage[x:x+height_baba_image,y:y+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            return Fitness
        else:
            width = width_group_image-width_baba_image
            temp_slice = groupImage[x:x+height_baba_image,
                                    width:width+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            return Fitness
            
    else:
        height = height_group_image-height_baba_image
        check_width = width_group_image - y
        if check_width >= width_baba_image:
            temp_slice = groupImage[height:height+height_baba_image,y:y+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            return Fitness
        else:
            width = width_group_image-width_baba_image
            temp_slice = groupImage[height:height+height_baba_image,
                                    width:width+width_baba_image]
            Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
            Fitness = float(Fitness[0][1])
            return Fitness

# %%
if sorted_pop_50[0][0] >= 0.9:
    print("Baba Ji is found in First Generation")
    print(sorted_pop_50[0][0])
else:
    #Cross over and mutation for evolution towards best possibly match for baba g
    Best_match = sorted_pop_50[0][0]
    print(Best_match)
    a=1
    while a!=100000:
        if sorted_pop_50[0][0] >= 0.9:
            print(f"Baba Ji is found in Generation {a}")
            print(sorted_pop_50[0])
            break
        Second_parent = 1
        print(f"Best Fitness before cross over {sorted_pop_50[0][0]}")
        for i in range(0,len(sorted_pop_50),2):
            x1 = sorted_pop_50[i][1]
            y1 = sorted_pop_50[i][2]
            x2 = sorted_pop_50[Second_parent][1]
            y2 = sorted_pop_50[Second_parent][2]
            New_Generation = Cross_over_mutation(x1,y1,x2,y2,height_group_image,width_group_image)
            for i in range(2):
                if i == 0:
                    Fitness = fitness(x1,y1,height_baba_image,width_baba_image,height_group_image,width_group_image,groupImage,baba_g)
                    sorted_pop_50[i][0] = Fitness
                    sorted_pop_50[i][1] = New_Generation[0]
                    sorted_pop_50[i][2] = New_Generation[1]
                else:
                    Fitness = fitness(x2,y2,height_baba_image,width_baba_image,height_group_image,width_group_image,groupImage,baba_g)
                    sorted_pop_50[Second_parent][0] = Fitness
                    sorted_pop_50[Second_parent][1] = New_Generation[2]
                    sorted_pop_50[Second_parent][2] = New_Generation[3]
            Second_parent = Second_parent + 2                                                                                                                                                                                         
        a = a + 1
        sorted_pop_50 = sorted(sorted_pop_50,key=lambda x:x[0],reverse=True)
        print(f"Best Fitness after cross over {sorted_pop_50[0][0]}")
        print(f"Generation number still searching {a}")
# Out:
# 0.3661975987094428
# Best Fitness before cross over 0.3661975987094428
# Best Fitness after cross over 0.350890269798597
# Generation number still searching 2
# Best Fitness before cross over 0.350890269798597
# Best Fitness after cross over 0.3319353896524027
# Generation number still searching 3
# Best Fitness before cross over 0.3319353896524027
# Best Fitness after cross over 0.40793451479290865
# Generation number still searching 4
# Best Fitness before cross over 0.40793451479290865
# Best Fitness after cross over 0.4228329884415713
# Generation number still searching 5
# Best Fitness before cross over 0.4228329884415713
# Best Fitness after cross over 0.5246757002144878
# Generation number still searching 6
# Best Fitness before cross over 0.5246757002144878
# Best Fitness after cross over 0.36314047061171895
# Generation number still searching 7
# Best Fitness before cross over 0.36314047061171895
# Best Fitness after cross over 0.4261896934349874
# Generation number still searching 8
# Best Fitness before cross over 0.4261896934349874
# Best Fitness after cross over 0.6383844740416049
# Generation number still searching 9
# Best Fitness before cross over 0.6383844740416049
# Best Fitness after cross over 0.4429116816712136
# Generation number still searching 10
# Best Fitness before cross over 0.4429116816712136
# Best Fitness after cross over 0.4150400714348239
# Generation number still searching 11
# Best Fitness before cross over 0.4150400714348239
# Best Fitness after cross over 0.5187374529297989
# Generation number still searching 12
# Best Fitness before cross over 0.5187374529297989
# Best Fitness after cross over 0.42295453356221546
# Generation number still searching 13
# Best Fitness before cross over 0.42295453356221546
# Best Fitness after cross over 0.4322123928823396
# Generation number still searching 14
# Best Fitness before cross over 0.4322123928823396
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 15
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.47554791964044074
# Generation number still searching 16
# Best Fitness before cross over 0.47554791964044074
# Best Fitness after cross over 0.510919208987428
# Generation number still searching 17
# Best Fitness before cross over 0.510919208987428
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 18
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.4299817215311813
# Generation number still searching 19
# Best Fitness before cross over 0.4299817215311813
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 20
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.43730363196325156
# Generation number still searching 21
# Best Fitness before cross over 0.43730363196325156
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 22
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4508863393696982
# Generation number still searching 23
# Best Fitness before cross over 0.4508863393696982
# Best Fitness after cross over 0.4265118540808446
# Generation number still searching 24
# Best Fitness before cross over 0.4265118540808446
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 25
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 26
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.479049098656414
# Generation number still searching 27
# Best Fitness before cross over 0.479049098656414
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 28
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 29
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.44278347665408113
# Generation number still searching 30
# Best Fitness before cross over 0.44278347665408113
# Best Fitness after cross over 0.4741621620931449
# Generation number still searching 31
# Best Fitness before cross over 0.4741621620931449
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 32
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 33
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 34
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 35
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.4422686948078119
# Generation number still searching 36
# Best Fitness before cross over 0.4422686948078119
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 37
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 38
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 39
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 40
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.4278622141478636
# Generation number still searching 41
# Best Fitness before cross over 0.4278622141478636
# Best Fitness after cross over 0.5247858956209854
# Generation number still searching 42
# Best Fitness before cross over 0.5247858956209854
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 43
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 44
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4310470637133962
# Generation number still searching 45
# Best Fitness before cross over 0.4310470637133962
# Best Fitness after cross over 0.4318967604976071
# Generation number still searching 46
# Best Fitness before cross over 0.4318967604976071
# Best Fitness after cross over 0.5753514314137466
# Generation number still searching 47
# Best Fitness before cross over 0.5753514314137466
# Best Fitness after cross over 0.4608024554731736
# Generation number still searching 48
# Best Fitness before cross over 0.4608024554731736
# Best Fitness after cross over 0.4705605463724414
# Generation number still searching 49
# Best Fitness before cross over 0.4705605463724414
# Best Fitness after cross over 0.47377597703603586
# Generation number still searching 50
# Best Fitness before cross over 0.47377597703603586
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 51
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 52
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 53
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.43013076251882276
# Generation number still searching 54
# Best Fitness before cross over 0.43013076251882276
# Best Fitness after cross over 0.43325480335901645
# Generation number still searching 55
# Best Fitness before cross over 0.43325480335901645
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 56
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4344369353053346
# Generation number still searching 57
# Best Fitness before cross over 0.4344369353053346
# Best Fitness after cross over 0.4309816552492496
# Generation number still searching 58
# Best Fitness before cross over 0.4309816552492496
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 59
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.44755758186796574
# Generation number still searching 60
# Best Fitness before cross over 0.44755758186796574
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 61
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 62
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 63
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.6621547690655948
# Generation number still searching 64
# Best Fitness before cross over 0.6621547690655948
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 65
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.431662304226273
# Generation number still searching 66
# Best Fitness before cross over 0.431662304226273
# Best Fitness after cross over 0.4340580573463666
# Generation number still searching 67
# Best Fitness before cross over 0.4340580573463666
# Best Fitness after cross over 0.543231922044523
# Generation number still searching 68
# Best Fitness before cross over 0.543231922044523
# Best Fitness after cross over 0.543231922044523
# Generation number still searching 69
# Best Fitness before cross over 0.543231922044523
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 70
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 71
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.45334172592670813
# Generation number still searching 72
# Best Fitness before cross over 0.45334172592670813
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 73
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4344369353053346
# Generation number still searching 74
# Best Fitness before cross over 0.4344369353053346
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 75
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.43656213388078174
# Generation number still searching 76
# Best Fitness before cross over 0.43656213388078174
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 77
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4321753863688033
# Generation number still searching 78
# Best Fitness before cross over 0.4321753863688033
# Best Fitness after cross over 0.48643318446184397
# Generation number still searching 79
# Best Fitness before cross over 0.48643318446184397
# Best Fitness after cross over 0.4366129064113515
# Generation number still searching 80
# Best Fitness before cross over 0.4366129064113515
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 81
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 82
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 83
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 84
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 85
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4596444286515529
# Generation number still searching 86
# Best Fitness before cross over 0.4596444286515529
# Best Fitness after cross over 0.43946626135522376
# Generation number still searching 87
# Best Fitness before cross over 0.43946626135522376
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 88
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.6008002867051624
# Generation number still searching 89
# Best Fitness before cross over 0.6008002867051624
# Best Fitness after cross over 0.4626568857973702
# Generation number still searching 90
# Best Fitness before cross over 0.4626568857973702
# Best Fitness after cross over 0.45327826691135775
# Generation number still searching 91
# Best Fitness before cross over 0.45327826691135775
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 92
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43480277697502734
# Generation number still searching 93
# Best Fitness before cross over 0.43480277697502734
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 94
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.4945963563708551
# Generation number still searching 95
# Best Fitness before cross over 0.4945963563708551
# Best Fitness after cross over 0.4507691550155316
# Generation number still searching 96
# Best Fitness before cross over 0.4507691550155316
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 97
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 98
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 99
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.43013076251882276
# Generation number still searching 100
# Best Fitness before cross over 0.43013076251882276
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 101
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.43133780107977654
# Generation number still searching 102
# Best Fitness before cross over 0.43133780107977654
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 103
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.43194954592100765
# Generation number still searching 104
# Best Fitness before cross over 0.43194954592100765
# Best Fitness after cross over 0.4268082833493541
# Generation number still searching 105
# Best Fitness before cross over 0.4268082833493541
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 106
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 107
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 108
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.43260582428671474
# Generation number still searching 109
# Best Fitness before cross over 0.43260582428671474
# Best Fitness after cross over 0.4534173715533115
# Generation number still searching 110
# Best Fitness before cross over 0.4534173715533115
# Best Fitness after cross over 0.446472931353446
# Generation number still searching 111
# Best Fitness before cross over 0.446472931353446
# Best Fitness after cross over 0.6087489634274122
# Generation number still searching 112
# Best Fitness before cross over 0.6087489634274122
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 113
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4406549050448495
# Generation number still searching 114
# Best Fitness before cross over 0.4406549050448495
# Best Fitness after cross over 0.43656213388078174
# Generation number still searching 115
# Best Fitness before cross over 0.43656213388078174
# Best Fitness after cross over 0.4318967604976071
# Generation number still searching 116
# Best Fitness before cross over 0.4318967604976071
# Best Fitness after cross over 0.4543636524267187
# Generation number still searching 117
# Best Fitness before cross over 0.4543636524267187
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 118
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.4310470637133962
# Generation number still searching 119
# Best Fitness before cross over 0.4310470637133962
# Best Fitness after cross over 0.4310470637133962
# Generation number still searching 120
# Best Fitness before cross over 0.4310470637133962
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 121
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 122
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 123
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.43194730007255006
# Generation number still searching 124
# Best Fitness before cross over 0.43194730007255006
# Best Fitness after cross over 0.4316259885825311
# Generation number still searching 125
# Best Fitness before cross over 0.4316259885825311
# Best Fitness after cross over 0.6875545179145547
# Generation number still searching 126
# Best Fitness before cross over 0.6875545179145547
# Best Fitness after cross over 0.4531593049930328
# Generation number still searching 127
# Best Fitness before cross over 0.4531593049930328
# Best Fitness after cross over 0.5273020674296387
# Generation number still searching 128
# Best Fitness before cross over 0.5273020674296387
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 129
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.43480277697502734
# Generation number still searching 130
# Best Fitness before cross over 0.43480277697502734
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 131
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 132
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 133
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 134
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 135
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 136
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.450026727580235
# Generation number still searching 137
# Best Fitness before cross over 0.450026727580235
# Best Fitness after cross over 0.450026727580235
# Generation number still searching 138
# Best Fitness before cross over 0.450026727580235
# Best Fitness after cross over 0.450026727580235
# Generation number still searching 139
# Best Fitness before cross over 0.450026727580235
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 140
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.44694850559882376
# Generation number still searching 141
# Best Fitness before cross over 0.44694850559882376
# Best Fitness after cross over 0.43480277697502734
# Generation number still searching 142
# Best Fitness before cross over 0.43480277697502734
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 143
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 144
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 145
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 146
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 147
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 148
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 149
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 150
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 151
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 152
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.4344369353053346
# Generation number still searching 153
# Best Fitness before cross over 0.4344369353053346
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 154
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.5625136762454508
# Generation number still searching 155
# Best Fitness before cross over 0.5625136762454508
# Best Fitness after cross over 0.4344369353053346
# Generation number still searching 156
# Best Fitness before cross over 0.4344369353053346
# Best Fitness after cross over 0.5741889366710952
# Generation number still searching 157
# Best Fitness before cross over 0.5741889366710952
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 158
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 159
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.43194730007255006
# Generation number still searching 160
# Best Fitness before cross over 0.43194730007255006
# Best Fitness after cross over 0.5824300294632739
# Generation number still searching 161
# Best Fitness before cross over 0.5824300294632739
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 162
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.43656213388078174
# Generation number still searching 163
# Best Fitness before cross over 0.43656213388078174
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 164
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 165
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 166
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.49038294947802563
# Generation number still searching 167
# Best Fitness before cross over 0.49038294947802563
# Best Fitness after cross over 0.4777080201577413
# Generation number still searching 168
# Best Fitness before cross over 0.4777080201577413
# Best Fitness after cross over 0.43548624225647703
# Generation number still searching 169
# Best Fitness before cross over 0.43548624225647703
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 170
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 171
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 172
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 173
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 174
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 175
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 176
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 177
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4270319199295152
# Generation number still searching 178
# Best Fitness before cross over 0.4270319199295152
# Best Fitness after cross over 0.4321753863688033
# Generation number still searching 179
# Best Fitness before cross over 0.4321753863688033
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 180
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.4289508587911621
# Generation number still searching 181
# Best Fitness before cross over 0.4289508587911621
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 182
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 183
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 184
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.43121016126456946
# Generation number still searching 185
# Best Fitness before cross over 0.43121016126456946
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 186
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 187
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 188
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 189
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 190
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 191
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 192
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 193
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 194
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 195
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.5062435398195663
# Generation number still searching 196
# Best Fitness before cross over 0.5062435398195663
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 197
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 198
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.42365764123405564
# Generation number still searching 199
# Best Fitness before cross over 0.42365764123405564
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 200
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 201
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.4277103623326927
# Generation number still searching 202
# Best Fitness before cross over 0.4277103623326927
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 203
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4265118540808446
# Generation number still searching 204
# Best Fitness before cross over 0.4265118540808446
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 205
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 206
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 207
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 208
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.42988640499448383
# Generation number still searching 209
# Best Fitness before cross over 0.42988640499448383
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 210
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 211
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4316259885825311
# Generation number still searching 212
# Best Fitness before cross over 0.4316259885825311
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 213
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 214
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.455671959347263
# Generation number still searching 215
# Best Fitness before cross over 0.455671959347263
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 216
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 217
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 218
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.47847690679138183
# Generation number still searching 219
# Best Fitness before cross over 0.47847690679138183
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 220
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 221
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.45775903697954756
# Generation number still searching 222
# Best Fitness before cross over 0.45775903697954756
# Best Fitness after cross over 0.43249411991728
# Generation number still searching 223
# Best Fitness before cross over 0.43249411991728
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 224
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.43663562738772177
# Generation number still searching 225
# Best Fitness before cross over 0.43663562738772177
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 226
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.5033048695426587
# Generation number still searching 227
# Best Fitness before cross over 0.5033048695426587
# Best Fitness after cross over 0.5281268639001383
# Generation number still searching 228
# Best Fitness before cross over 0.5281268639001383
# Best Fitness after cross over 0.5247858956209854
# Generation number still searching 229
# Best Fitness before cross over 0.5247858956209854
# Best Fitness after cross over 0.44654896089801227
# Generation number still searching 230
# Best Fitness before cross over 0.44654896089801227
# Best Fitness after cross over 0.4598047073645372
# Generation number still searching 231
# Best Fitness before cross over 0.4598047073645372
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 232
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4424873239362458
# Generation number still searching 233
# Best Fitness before cross over 0.4424873239362458
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 234
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.43730363196325156
# Generation number still searching 235
# Best Fitness before cross over 0.43730363196325156
# Best Fitness after cross over 0.4344369353053346
# Generation number still searching 236
# Best Fitness before cross over 0.4344369353053346
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 237
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 238
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.6354405038495987
# Generation number still searching 239
# Best Fitness before cross over 0.6354405038495987
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 240
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 241
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 242
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 243
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.43730363196325156
# Generation number still searching 244
# Best Fitness before cross over 0.43730363196325156
# Best Fitness after cross over 0.4366129064113515
# Generation number still searching 245
# Best Fitness before cross over 0.4366129064113515
# Best Fitness after cross over 0.43325480335901645
# Generation number still searching 246
# Best Fitness before cross over 0.43325480335901645
# Best Fitness after cross over 0.43695059811324993
# Generation number still searching 247
# Best Fitness before cross over 0.43695059811324993
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 248
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 249
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.5033048695426587
# Generation number still searching 250
# Best Fitness before cross over 0.5033048695426587
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 251
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 252
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 253
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.4322123928823396
# Generation number still searching 254
# Best Fitness before cross over 0.4322123928823396
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 255
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.43013076251882276
# Generation number still searching 256
# Best Fitness before cross over 0.43013076251882276
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 257
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 258
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.45187269193658336
# Generation number still searching 259
# Best Fitness before cross over 0.45187269193658336
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 260
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.4601626448031336
# Generation number still searching 261
# Best Fitness before cross over 0.4601626448031336
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 262
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.431662304226273
# Generation number still searching 263
# Best Fitness before cross over 0.431662304226273
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 264
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.4403645609470193
# Generation number still searching 265
# Best Fitness before cross over 0.4403645609470193
# Best Fitness after cross over 0.4366129064113515
# Generation number still searching 266
# Best Fitness before cross over 0.4366129064113515
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 267
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 268
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 269
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 270
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.43480277697502734
# Generation number still searching 271
# Best Fitness before cross over 0.43480277697502734
# Best Fitness after cross over 0.44682378818475393
# Generation number still searching 272
# Best Fitness before cross over 0.44682378818475393
# Best Fitness after cross over 0.4475130129186853
# Generation number still searching 273
# Best Fitness before cross over 0.4475130129186853
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 274
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 275
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.5476385526343142
# Generation number still searching 276
# Best Fitness before cross over 0.5476385526343142
# Best Fitness after cross over 0.43548624225647703
# Generation number still searching 277
# Best Fitness before cross over 0.43548624225647703
# Best Fitness after cross over 0.46770166390087875
# Generation number still searching 278
# Best Fitness before cross over 0.46770166390087875
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 279
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.43881907798465536
# Generation number still searching 280
# Best Fitness before cross over 0.43881907798465536
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 281
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 282
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.43325480335901645
# Generation number still searching 283
# Best Fitness before cross over 0.43325480335901645
# Best Fitness after cross over 0.4523955528757503
# Generation number still searching 284
# Best Fitness before cross over 0.4523955528757503
# Best Fitness after cross over 0.4299817215311813
# Generation number still searching 285
# Best Fitness before cross over 0.4299817215311813
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 286
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 287
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.4668340549017095
# Generation number still searching 288
# Best Fitness before cross over 0.4668340549017095
# Best Fitness after cross over 0.5264315248232977
# Generation number still searching 289
# Best Fitness before cross over 0.5264315248232977
# Best Fitness after cross over 0.45775903697954756
# Generation number still searching 290
# Best Fitness before cross over 0.45775903697954756
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 291
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4880835107755247
# Generation number still searching 292
# Best Fitness before cross over 0.4880835107755247
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 293
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 294
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.43249411991728
# Generation number still searching 295
# Best Fitness before cross over 0.43249411991728
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 296
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 297
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 298
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4318967604976071
# Generation number still searching 299
# Best Fitness before cross over 0.4318967604976071
# Best Fitness after cross over 0.6035812866372745
# Generation number still searching 300
# Best Fitness before cross over 0.6035812866372745
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 301
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4303636876625681
# Generation number still searching 302
# Best Fitness before cross over 0.4303636876625681
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 303
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.4594970539933608
# Generation number still searching 304
# Best Fitness before cross over 0.4594970539933608
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 305
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43260582428671474
# Generation number still searching 306
# Best Fitness before cross over 0.43260582428671474
# Best Fitness after cross over 0.43325480335901645
# Generation number still searching 307
# Best Fitness before cross over 0.43325480335901645
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 308
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.454373529678164
# Generation number still searching 309
# Best Fitness before cross over 0.454373529678164
# Best Fitness after cross over 0.5224850161733228
# Generation number still searching 310
# Best Fitness before cross over 0.5224850161733228
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 311
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4768151216543273
# Generation number still searching 312
# Best Fitness before cross over 0.4768151216543273
# Best Fitness after cross over 0.46064091607889196
# Generation number still searching 313
# Best Fitness before cross over 0.46064091607889196
# Best Fitness after cross over 0.4766952906252087
# Generation number still searching 314
# Best Fitness before cross over 0.4766952906252087
# Best Fitness after cross over 0.4766952906252087
# Generation number still searching 315
# Best Fitness before cross over 0.4766952906252087
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 316
# Best Fitness before cross over 0.43659086130433
# Best Fitness after cross over 0.45773629540799377
# Generation number still searching 317
# Best Fitness before cross over 0.45773629540799377
# Best Fitness after cross over 0.43967024957178724
# Generation number still searching 318
# Best Fitness before cross over 0.43967024957178724
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 319
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 320
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 321
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.4299817215311813
# Generation number still searching 322
# Best Fitness before cross over 0.4299817215311813
# Best Fitness after cross over 0.4498703228062786
# Generation number still searching 323
# Best Fitness before cross over 0.4498703228062786
# Best Fitness after cross over 0.4498703228062786
# Generation number still searching 324
# Best Fitness before cross over 0.4498703228062786
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 325
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 326
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 327
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 328
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.43969073552309196
# Generation number still searching 329
# Best Fitness before cross over 0.43969073552309196
# Best Fitness after cross over 0.4608655908347627
# Generation number still searching 330
# Best Fitness before cross over 0.4608655908347627
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 331
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 332
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 333
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.4649884123499598
# Generation number still searching 334
# Best Fitness before cross over 0.4649884123499598
# Best Fitness after cross over 0.4991075546660207
# Generation number still searching 335
# Best Fitness before cross over 0.4991075546660207
# Best Fitness after cross over 0.5108369037000692
# Generation number still searching 336
# Best Fitness before cross over 0.5108369037000692
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 337
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.438831043267621
# Generation number still searching 338
# Best Fitness before cross over 0.438831043267621
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 339
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 340
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 341
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.5559919770806516
# Generation number still searching 342
# Best Fitness before cross over 0.5559919770806516
# Best Fitness after cross over 0.44654896089801227
# Generation number still searching 343
# Best Fitness before cross over 0.44654896089801227
# Best Fitness after cross over 0.4350367623398127
# Generation number still searching 344
# Best Fitness before cross over 0.4350367623398127
# Best Fitness after cross over 0.5576389491434353
# Generation number still searching 345
# Best Fitness before cross over 0.5576389491434353
# Best Fitness after cross over 0.4424873239362458
# Generation number still searching 346
# Best Fitness before cross over 0.4424873239362458
# Best Fitness after cross over 0.4386060900896387
# Generation number still searching 347
# Best Fitness before cross over 0.4386060900896387
# Best Fitness after cross over 0.4344369353053346
# Generation number still searching 348
# Best Fitness before cross over 0.4344369353053346
# Best Fitness after cross over 0.6841311048818048
# Generation number still searching 349
# Best Fitness before cross over 0.6841311048818048
# Best Fitness after cross over 0.4489081736906204
# Generation number still searching 350
# Best Fitness before cross over 0.4489081736906204
# Best Fitness after cross over 0.4530304467288698
# Generation number still searching 351
# Best Fitness before cross over 0.4530304467288698
# ...
# Generation number still searching 5121
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.45276070338259994
# Generation number still searching 5122
# Best Fitness before cross over 0.45276070338259994
# Best Fitness after cross over 0.4310470637133962
# Generation number still searching 5123
# Best Fitness before cross over 0.4310470637133962
# Best Fitness after cross over 0.45775903697954756
# Generation number still searching 5124
# Best Fitness before cross over 0.45775903697954756
# Best Fitness after cross over 0.4406663897088352
# Generation number still searching 5125
# Best Fitness before cross over 0.4406663897088352
# Best Fitness after cross over 0.43660228437676807
# Generation number still searching 5126
# Best Fitness before cross over 0.43660228437676807
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 5127
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.45669512602215095
# Generation number still searching 5128
# Best Fitness before cross over 0.45669512602215095
# Best Fitness after cross over 0.43548624225647703
# Generation number still searching 5129
# Best Fitness before cross over 0.43548624225647703
# Best Fitness after cross over 0.43013076251882276
# Generation number still searching 5130
# Best Fitness before cross over 0.43013076251882276
# Best Fitness after cross over 0.42511881722770384
# Generation number still searching 5131
# Best Fitness before cross over 0.42511881722770384
# Best Fitness after cross over 0.42348207538006355
# Generation number still searching 5132
# Best Fitness before cross over 0.42348207538006355
# Best Fitness after cross over 0.49124132447009833
# Generation number still searching 5133
# Best Fitness before cross over 0.49124132447009833
# Best Fitness after cross over 0.5807712189644785
# Generation number still searching 5134
# Best Fitness before cross over 0.5807712189644785
# Best Fitness after cross over 0.5073265265357341
# Generation number still searching 5135
# Best Fitness before cross over 0.5073265265357341
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 5136
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 5137
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.4406549050448495
# Generation number still searching 5138
# Best Fitness before cross over 0.4406549050448495
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 5139
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.43700025003068327
# Generation number still searching 5140
# Best Fitness before cross over 0.43700025003068327
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 5141
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.4837963321381756
# Generation number still searching 5142
# Best Fitness before cross over 0.4837963321381756
# Best Fitness after cross over 0.4321753863688033
# Generation number still searching 5143
# Best Fitness before cross over 0.4321753863688033
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 5144
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.4320124271014397
# Generation number still searching 5145
# Best Fitness before cross over 0.4320124271014397
# Best Fitness after cross over 0.43121016126456946
# Generation number still searching 5146
# Best Fitness before cross over 0.43121016126456946
# Best Fitness after cross over 0.4330672186176507
# Generation number still searching 5147
# Best Fitness before cross over 0.4330672186176507
# Best Fitness after cross over 0.5013994075427357
# Generation number still searching 5148
# Best Fitness before cross over 0.5013994075427357
# Best Fitness after cross over 0.542652736749033
# Generation number still searching 5149
# Best Fitness before cross over 0.542652736749033
# Best Fitness after cross over 0.4310470637133962
# Generation number still searching 5150
# Best Fitness before cross over 0.4310470637133962
# Best Fitness after cross over 0.43249411991728
# Generation number still searching 5151
# Best Fitness before cross over 0.43249411991728
# Best Fitness after cross over 0.4253507428654261
# Generation number still searching 5152
# Best Fitness before cross over 0.4253507428654261
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 5153
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.49951108297919034
# Generation number still searching 5154
# Best Fitness before cross over 0.49951108297919034
# Best Fitness after cross over 0.43548624225647703
# Generation number still searching 5155
# Best Fitness before cross over 0.43548624225647703
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 5156
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.5486441965715744
# Generation number still searching 5157
# Best Fitness before cross over 0.5486441965715744
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 5158
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.4321753863688033
# Generation number still searching 5159
# Best Fitness before cross over 0.4321753863688033
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 5160
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.43969073552309196
# Generation number still searching 5161
# Best Fitness before cross over 0.43969073552309196
# Best Fitness after cross over 0.4310470637133962
# Generation number still searching 5162
# Best Fitness before cross over 0.4310470637133962
# Best Fitness after cross over 0.6434494889276191
# Generation number still searching 5163
# Best Fitness before cross over 0.6434494889276191
# Best Fitness after cross over 0.46011487682205576
# Generation number still searching 5164
# Best Fitness before cross over 0.46011487682205576
# Best Fitness after cross over 0.5086030138669985
# Generation number still searching 5165
# Best Fitness before cross over 0.5086030138669985
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 5166
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.4406549050448495
# Generation number still searching 5167
# Best Fitness before cross over 0.4406549050448495
# Best Fitness after cross over 0.45403707420243217
# Generation number still searching 5168
# Best Fitness before cross over 0.45403707420243217
# Best Fitness after cross over 0.5782985165173717
# Generation number still searching 5169
# Best Fitness before cross over 0.5782985165173717
# Best Fitness after cross over 0.4358911683796676
# Generation number still searching 5170
# Best Fitness before cross over 0.4358911683796676
# Best Fitness after cross over 0.4274564932094338
# Generation number still searching 5171
# Best Fitness before cross over 0.4274564932094338
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 5172
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 5173
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.482540407234688
# Generation number still searching 5174
# Best Fitness before cross over 0.482540407234688
# Best Fitness after cross over 0.5486441965715744
# Generation number still searching 5175
# Best Fitness before cross over 0.5486441965715744
# Best Fitness after cross over 0.6576842344778622
# Generation number still searching 5176
# Best Fitness before cross over 0.6576842344778622
# Best Fitness after cross over 0.4605273374719867
# Generation number still searching 5177
# Best Fitness before cross over 0.4605273374719867
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 5178
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.44311538503229714
# Generation number still searching 5179
# Best Fitness before cross over 0.44311538503229714
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 5180
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 5181
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.43194730007255006
# Generation number still searching 5182
# Best Fitness before cross over 0.43194730007255006
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 5183
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 5184
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 5185
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.43425444433729876
# Generation number still searching 5186
# Best Fitness before cross over 0.43425444433729876
# Best Fitness after cross over 0.4322123928823396
# Generation number still searching 5187
# Best Fitness before cross over 0.4322123928823396
# Best Fitness after cross over 0.4550778482325139
# Generation number still searching 5188
# Best Fitness before cross over 0.4550778482325139
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 5189
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.4356701678692654
# Generation number still searching 5190
# Best Fitness before cross over 0.4356701678692654
# Best Fitness after cross over 0.43663562738772177
# Generation number still searching 5191
# Best Fitness before cross over 0.43663562738772177
# Best Fitness after cross over 0.43266691561327125
# Generation number still searching 5192
# Best Fitness before cross over 0.43266691561327125
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 5193
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.4374506549505584
# Generation number still searching 5194
# Best Fitness before cross over 0.4374506549505584
# Best Fitness after cross over 0.5571829811361725
# Generation number still searching 5195
# Best Fitness before cross over 0.5571829811361725
# Best Fitness after cross over 0.5086030138669985
# Generation number still searching 5196
# Best Fitness before cross over 0.5086030138669985
# Best Fitness after cross over 0.43480277697502734
# Generation number still searching 5197
# Best Fitness before cross over 0.43480277697502734
# Best Fitness after cross over 0.5370661630596288
# Generation number still searching 5198
# Best Fitness before cross over 0.5370661630596288
# Best Fitness after cross over 0.5576389491434353
# Generation number still searching 5199
# Best Fitness before cross over 0.5576389491434353
# Best Fitness after cross over 0.5608759107060091
# Generation number still searching 5200
# Best Fitness before cross over 0.5608759107060091
# Best Fitness after cross over 0.4496250947677417
# Generation number still searching 5201
# Best Fitness before cross over 0.4496250947677417
# Best Fitness after cross over 0.49574297686518515
# Generation number still searching 5202
# Best Fitness before cross over 0.49574297686518515
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 5203
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.4377215110764511
# Generation number still searching 5204
# Best Fitness before cross over 0.4377215110764511
# Best Fitness after cross over 0.454373529678164
# Generation number still searching 5205
# Best Fitness before cross over 0.454373529678164
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 5206
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.597733061501623
# Generation number still searching 5207
# Best Fitness before cross over 0.597733061501623
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 5208
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 5209
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.455671959347263
# Generation number still searching 5210
# Best Fitness before cross over 0.455671959347263
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 5211
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.5053732188220466
# Generation number still searching 5212
# Best Fitness before cross over 0.5053732188220466
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 5213
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 5214
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.47453228717546814
# Generation number still searching 5215
# Best Fitness before cross over 0.47453228717546814
# Best Fitness after cross over 0.43631246863295164
# Generation number still searching 5216
# Best Fitness before cross over 0.43631246863295164
# Best Fitness after cross over 0.43546687601417283
# Generation number still searching 5217
# Best Fitness before cross over 0.43546687601417283
# Best Fitness after cross over 0.43957560579026517
# Generation number still searching 5218
# Best Fitness before cross over 0.43957560579026517
# Best Fitness after cross over 0.4299817215311813
# Generation number still searching 5219
# Best Fitness before cross over 0.4299817215311813
# Best Fitness after cross over 0.4376390993481544
# Generation number still searching 5220
# Best Fitness before cross over 0.4376390993481544
# Best Fitness after cross over 0.44487319390137087
# Generation number still searching 5221
# Best Fitness before cross over 0.44487319390137087
# Best Fitness after cross over 0.4383966776234294
# Generation number still searching 5222
# Best Fitness before cross over 0.4383966776234294
# Best Fitness after cross over 0.438588296815028
# Generation number still searching 5223
# Best Fitness before cross over 0.438588296815028
# Best Fitness after cross over 0.43659086130433
# Generation number still searching 5224
# Best Fitness before cross over 0.43659086130433
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-495540bbd902> in <module>
#      22             for i in range(2):
#      23                 if i == 0:
# ---> 24                     Fitness = fitness(x1,y1,height_baba_image,width_baba_image,height_group_image,width_group_image,groupImage,baba_g)
#      25                     sorted_pop_50[i][0] = Fitness
#      26                     sorted_pop_50[i][1] = New_Generation[0]
#
# <ipython-input-7-c283d123ef1f> in fitness(x, y, height_baba_image, width_baba_image, height_group_image, width_group_image, groupImage, baba_g)
#      73         if check_width >= width_baba_image:
#      74             temp_slice = groupImage[x:x+height_baba_image,y:y+width_baba_image]
# ---> 75             Fitness = np.corrcoef(baba_g.flatten(),temp_slice.flatten())
#      76             Fitness = float(Fitness[0][1])
#      77             return Fitness
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2520         warnings.warn('bias and ddof have no effect and are deprecated',
#    2521                       DeprecationWarning, stacklevel=2)
# -> 2522     c = cov(x, y, rowvar)
#    2523     try:
#    2524         d = diag(c)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2375         dtype = np.result_type(m, y, np.float64)
#    2376
# -> 2377     X = array(m, ndmin=2, dtype=dtype)
#    2378     if not rowvar and X.shape[0] != 1:
#    2379         X = X.T
#
# KeyboardInterrupt:

# %%
# Out:
# 1000

# %%
# Out:
# 10
