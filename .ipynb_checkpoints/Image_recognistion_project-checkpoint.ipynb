# %%
from matplotlib import pyplot

# %%
groupImage = pyplot.imread("groupGray.jpg")
baba_g = pyplot.imread("boothiGray.jpg")
print(pyplot.imshow(groupImage))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
print(pyplot.imshow(baba_g))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
groupImage.shape
# Out:
# (512, 1024)

# %%
groupImage.size
# Out:
# 524288

# %%
type(groupImage)
# Out:
# numpy.ndarray

# %%
print(groupImage)
# Out:
# [[31 31 31 ...  4  4  5]
#  [31 31 31 ...  3  3  3]
#  [31 31 31 ...  3  2  2]
#  ...
#  [ 8  9 10 ...  8  7  7]
#  [ 9 10 11 ...  8  8  8]
#  [ 9 10 11 ...  9  9  9]]

# %%
slice = groupImage[:,:512]

# %%
pyplot.imshow(slice)

# %%
slice2 = groupImage[:,512:]

# %%
pyplot.imshow(slice2)

# %%
pyplot.imshow(groupImage)

# %%
slice3 = groupImage[100:136,630:700]

# %%
pyplot.imshow(slice3)
